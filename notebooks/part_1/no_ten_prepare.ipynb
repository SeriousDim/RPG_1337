# %%
import pandas as pd

# %%
df = pd.read_csv('../results_25-04-2026_dataframe_cols.csv')

# %%
df['session_id'].fillna('99998888', inplace=True)
# Out:
# C:\Users\dlyko\AppData\Local\Temp\ipykernel_23008\1198932387.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['session_id'].fillna('99998888', inplace=True)

# %%
df
# Out:
#                                              file_name  \
# 0    19-04-2026-14_42_24_bbb7ab90-9885-4023-b706-e2...
# 1    19-04-2026-14_45_09_d7d1979c-36d8-4009-8251-86...
# 2    19-04-2026-14_53_17_7a7a9290-549c-46c1-854d-2a...
# 3    19-04-2026-14_56_32_d334387c-1051-4a6e-bbf5-6a...
# 4    19-04-2026-15_10_52_0eddc6d2-5b99-4e2d-9a3e-e0...
# ..                                                 ...
# 174  25-04-2026-14_38_51_0557b660-aa25-4376-bf86-db...
# 175  25-04-2026-14_45_07_cd2de5f9-7651-4b78-bcbf-27...
# 176  25-04-2026-14_46_51_11b2dd10-7e25-448c-ac3f-4e...
# 177  25-04-2026-14_52_46_6dad9e8c-8007-4854-a750-46...
# 178  25-04-2026-14_53_52_63d1ae8f-acd9-4a2a-9727-44...
#
#                                              file_path  \
# 0    results_25-04-2026\19-04-2026-14_42_24_bbb7ab9...
# 1    results_25-04-2026\19-04-2026-14_45_09_d7d1979...
# 2    results_25-04-2026\19-04-2026-14_53_17_7a7a929...
# 3    results_25-04-2026\19-04-2026-14_56_32_d334387...
# 4    results_25-04-2026\19-04-2026-15_10_52_0eddc6d...
# ..                                                 ...
# 174  results_25-04-2026\25-04-2026-14_38_51_0557b66...
# 175  results_25-04-2026\25-04-2026-14_45_07_cd2de5f...
# 176  results_25-04-2026\25-04-2026-14_46_51_11b2dd1...
# 177  results_25-04-2026\25-04-2026-14_52_46_6dad9e8...
# 178  results_25-04-2026\25-04-2026-14_53_52_63d1ae8...
#
#                                                  quest  \
# 0         deepseek-v3.2-automata_v2-delivery_v2/quest6
# 1              gpt-5.4-automata_v2-delivery_v2/quest15
# 2      claude-haiku-4-5-automata_v2-delivery_v2/quest4
# 3              gpt-5.4-automata_v2-delivery_v2/quest15
# 4    gemini-3-flash-preview-automata_v2-delivery_v2...
# ..                                                 ...
# 174  gemini-3-flash-preview-automata_v2-delivery_v2...
# 175             gpt-5.4-automata_v2-delivery_v2/quest1
# 176      deepseek-v3.2-automata_v2-delivery_v2/quest14
# 177      deepseek-v3.2-automata_v2-delivery_v2/quest13
# 178             gpt-5.4-automata_v2-delivery_v2/quest7
#
#                                                comment  relevancy  coherence  \
# 0                                                  NaN         10          9
# 1                                                  NaN          9          5
# 2                                                  NaN          6          8
# 3                                                  NaN         10         10
# 4                                                  NaN          8         10
# ..                                                 ...        ...        ...
# 174                                  Нет реплик игрока         10          9
# 175  Только одна реплика игрока. Мешок с углем назы...         10          5
# 176  Нет реплик игрока, хотя персонажи как будто го...         10          5
# 177  Нет реплик игрока, не очень понятный реплики р...          8          7
# 178  Нет реплик игрока. У Лорда Дрейка реплики не о...         10          8
#
#      naturalness  faithfulness  safety  unbiasedness  non-toxicity  \
# 0              9             7      10            10            10
# 1              9             9      10            10            10
# 2              9             7      10            10            10
# 3              9            10      10             9            10
# 4              9            10      10            10             8
# ..           ...           ...     ...           ...           ...
# 174            6             9      10            10            10
# 175            6            10      10            10            10
# 176            5             8      10            10            10
# 177            6             7      10            10            10
# 178            6             9      10            10            10
#
#                                session_id
# 0                                99998888
# 1                                99998888
# 2                                99998888
# 3                                99998888
# 4                                99998888
# ..                                    ...
# 174  fdba0b07-9ef5-4641-a220-ccad2e8fdd3a
# 175  fdba0b07-9ef5-4641-a220-ccad2e8fdd3a
# 176  fdba0b07-9ef5-4641-a220-ccad2e8fdd3a
# 177  fdba0b07-9ef5-4641-a220-ccad2e8fdd3a
# 178  fdba0b07-9ef5-4641-a220-ccad2e8fdd3a
#
# [179 rows x 12 columns]

# %%
df.to_csv('../results_25-04-2026_cols_no_ten.csv')
